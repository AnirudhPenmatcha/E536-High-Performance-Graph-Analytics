# %%
# !pip3 install neo4j-driver
# !pip3 install graphdatascience
# %matplotlib inline

import json
import time

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm
from neo4j import GraphDatabase, basic_auth
from graphdatascience import GraphDataScience as gds
#from neo4j import GraphDataScience as gds
# Out:
# Requirement already satisfied: neo4j-driver in c:\users\user\anaconda3\lib\site-packages (5.19.0)
# Requirement already satisfied: pytz in c:\users\user\anaconda3\lib\site-packages (from neo4j-driver) (2022.7)
# Requirement already satisfied: graphdatascience in c:\users\user\anaconda3\lib\site-packages (1.10)
# Requirement already satisfied: multimethod<2.0,>=1.0 in c:\users\user\anaconda3\lib\site-packages (from graphdatascience) (1.11.2)
# Requirement already satisfied: neo4j<6.0,>=4.4.2 in c:\users\user\anaconda3\lib\site-packages (from graphdatascience) (5.19.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\user\anaconda3\lib\site-packages (from graphdatascience) (1.5.3)
# Requirement already satisfied: pyarrow<16.0,>=11.0 in c:\users\user\anaconda3\lib\site-packages (from graphdatascience) (11.0.0)
# Requirement already satisfied: textdistance<5.0,>=4.0 in c:\users\user\anaconda3\lib\site-packages (from graphdatascience) (4.2.1)
# Requirement already satisfied: tqdm<5.0,>=4.0 in c:\users\user\anaconda3\lib\site-packages (from graphdatascience) (4.65.0)
# Requirement already satisfied: typing-extensions<5.0,>=4.0 in c:\users\user\anaconda3\lib\site-packages (from graphdatascience) (4.7.1)
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (from graphdatascience) (2.31.0)
# Requirement already satisfied: pytz in c:\users\user\anaconda3\lib\site-packages (from neo4j<6.0,>=4.4.2->graphdatascience) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\user\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->graphdatascience) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\user\anaconda3\lib\site-packages (from pandas<3.0,>=1.0->graphdatascience) (1.24.3)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm<5.0,>=4.0->graphdatascience) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests->graphdatascience) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests->graphdatascience) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests->graphdatascience) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests->graphdatascience) (2024.2.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas<3.0,>=1.0->graphdatascience) (1.16.0)

# %%
# A wrapper class to manage connection
class Neo4jConnection:
    
    def __init__(self, uri, user, pwd):
        self.__uri = uri
        self.__user = user
        self.__pwd = pwd
        self.__driver = None
        try:
            self.__driver = GraphDatabase.driver( self.__uri, auth=basic_auth(self.__user, self.__pwd))
        except Exception as e:
            print("Failed to create the driver:", e)
        
    def close(self):
        if self.__driver is not None:
            self.__driver.close()
        
    def query(self, query, parameters=None, db=None):
        assert self.__driver is not None, "Driver not initialized!"
        session = None
        response = None
        try: 
            session = self.__driver.session(database=db) if db is not None else self.__driver.session() 
            response = list(session.run(query, parameters))
        except Exception as e:
            print("Query failed:", e)
        finally: 
            if session is not None:
                session.close()
        return response

# %%
# Actually create a connection. Copy uri (with bolt port), username and passwords from your own sandbox instance
conn = Neo4jConnection(uri="bolt://44.210.130.105:7687", user="neo4j", pwd="bridge-warehouse-creek")

# %%
# clear data
# DETACH will remove add edges as well
query_string = '''
MATCH (c:Character) 
DETACH DELETE c;
'''
conn.query(query_string)

# read characters from season1 of GOT and add as Character nodes 
query_string = '''
WITH "https://raw.githubusercontent.com/mathbeveridge/gameofthrones/master/data/got-s1-nodes.csv" AS uri
LOAD CSV WITH HEADERS FROM uri AS row 
MERGE (c:Character {id:row.Id})
SET c.name = row.Label
'''
conn.query(query_string)

# read character interactions from season1 of GOT and add as edges
query_string = '''
WITH "https://raw.githubusercontent.com/mathbeveridge/gameofthrones/master/data/got-s1-edges.csv" AS uri
LOAD CSV WITH HEADERS FROM uri AS row
MATCH (source:Character {id: row.Source})
MATCH (target:Character {id: row.Target})
MERGE (source)-[:SEASON1 {weight: toInteger(row.Weight)}]-(target)
'''
conn.query(query_string)
# Out:
# []

# %%
i=2
while i<9:
    query_string = f'''
    WITH "https://raw.githubusercontent.com/mathbeveridge/gameofthrones/master/data/got-s{i}-nodes.csv" AS uri
    LOAD CSV WITH HEADERS FROM uri AS row 
    MERGE (c:Character {{id:row.Id}})
    SET c.name = row.Label
    '''
    
    conn.query(query_string)
    
    query_string = f'''
    WITH "https://raw.githubusercontent.com/mathbeveridge/gameofthrones/master/data/got-s{i}-edges.csv" AS uri
    LOAD CSV WITH HEADERS FROM uri AS row
    MATCH (source:Character {{id: row.Source}})
    MATCH (target:Character {{id: row.Target}})
    MERGE (source)-[:SEASON{i} {{weight: toInteger(row.Weight)}}]-(target)
    '''
    
    conn.query(query_string)
    
    i+=1

# %%
# See the degrees of nodes
i=2
while i<9:
    query_string = f'''
    MATCH (c:Character) 
    RETURN c.name, SIZE([(c)-[:SEASON{i}]->(s) | s]) AS inDegree 
    ORDER BY inDegree DESC 
    '''
    top_cat_df = pd.DataFrame([dict(_) for _ in conn.query(query_string)])
    print(top_cat_df.head(10))
    i+=1
# Out:
#      c.name  inDegree
# 0    Cersei        28
# 1      Arya        25
# 2   Joffrey        23
# 3   Catelyn        19
# 4     Bronn        15
# 5      Bran        13
# 6  Daenerys        13
# 7     Petyr        13
# 8   Brienne        13
# 9     Jaime        12
#     c.name  inDegree
# 0   Cersei        18
# 1     Bran        17
# 2  Catelyn        16
# 3     Arya        15
# 4    Bronn        14
# 5  Joffrey        14
# 6    Jaime        13
# 7      Jon        12
# 8   Edmure        12
# 9     Robb        10
#     c.name  inDegree
# 0   Cersei        28
# 1  Joffrey        26
# 2     Arya        24
# 3      Jon        20
# 4    Jaime        19
# 5  Ellaria        16
# 6     Bran        15
# 7    Grenn        15
# 8  Brienne        15
# 9  Craster        14
#      c.name  inDegree
# 0    Cersei        29
# 1     Petyr        20
# 2       Jon        18
# 3   Alliser        11
# 4      Arya        11
# 5     Bronn        11
# 6  Daenerys        11
# 7     Jaime        11
# 8     Gilly        10
# 9   Eddison         9
#      c.name  inDegree
# 0    Cersei        24
# 1       Jon        21
# 2     Davos        20
# 3      Arya        17
# 4  Daenerys        16
# 5     Jaime        16
# 6      Bran        14
# 7   Brienne        12
# 8    Bianca        11
# 9    Bobono        11
#      c.name  inDegree
# 0  Daenerys        28
# 1    Cersei        26
# 2       Jon        24
# 3   Brienne        22
# 4     Davos        22
# 5      Arya        18
# 6      Bran        16
# 7     Bronn        15
# 8    Sandor        15
# 9   Ellaria        15
#       c.name  inDegree
# 0       Arya        38
# 1   Daenerys        32
# 2    Brienne        30
# 3      Davos        30
# 4       Bran        29
# 5      Beric        26
# 6  Grey Worm        25
# 7       Alys        22
# 8     Gendry        20
# 9        Jon        20

# %%
query_string = '''
MATCH (c:Character) 
RETURN c.name, 
        SIZE([(c)-[:SEASON1]->() | 1]) AS season1_degree,
        SIZE([(c)-[:SEASON2]->() | 1]) AS season2_degree,
        SIZE([(c)-[:SEASON3]->() | 1]) AS season3_degree,
        SIZE([(c)-[:SEASON4]->() | 1]) AS season4_degree,
        SIZE([(c)-[:SEASON5]->() | 1]) AS season5_degree,
        SIZE([(c)-[:SEASON6]->() | 1]) AS season6_degree,
        SIZE([(c)-[:SEASON7]->() | 1]) AS season7_degree,
        SIZE([(c)-[:SEASON8]->() | 1]) AS season8_degree,
        (SIZE([(c)-[:SEASON1]->() | 1]) + 
        SIZE([(c)-[:SEASON2]->() | 1]) +
        SIZE([(c)-[:SEASON3]->() | 1]) +
        SIZE([(c)-[:SEASON4]->() | 1]) +
        SIZE([(c)-[:SEASON5]->() | 1]) +
        SIZE([(c)-[:SEASON6]->() | 1]) +
        SIZE([(c)-[:SEASON7]->() | 1]) +
        SIZE([(c)-[:SEASON8]->() | 1])) AS cmbdDegree 
ORDER BY cmbdDegree DESC 
'''
top_cat_df = pd.DataFrame([dict(_) for _ in conn.query(query_string)])
print(top_cat_df.head(10))
# Out:
#      c.name  season1_degree  season2_degree  season3_degree  season4_degree  \
# 0    Cersei              23              28              18              28
# 1      Arya              28              25              15              24
# 2  Daenerys              17              13              10              14
# 3       Jon              14               6              12              20
# 4      Bran              18              13              17              15
# 5     Jaime              16              12              13              19
# 6     Davos               0              11               8              12
# 7   Brienne               0              13               5              15
# 8   Joffrey              18              23              14              26
# 9     Bronn              12              15              14              14
#
#    season5_degree  season6_degree  season7_degree  season8_degree  cmbdDegree
# 0              29              24              26              16         192
# 1              11              17              18              38         176
# 2              11              16              28              32         141
# 3              18              21              24              20         135
# 4               3              14              16              29         125
# 5              11              16              12              16         115
# 6               8              20              22              30         111
# 7               8              12              22              30         105
# 8               7               4               8               2         102
# 9              11               6              15              11          98

# %%
query_string = '''
MATCH (c:Character) 
RETURN c.name, 
        SIZE([(c)-[:SEASON1]->() | 1]) AS season1_degree,
        SIZE([(c)-[:SEASON2]->() | 1]) AS season2_degree,
        SIZE([(c)-[:SEASON3]->() | 1]) AS season3_degree,
        SIZE([(c)-[:SEASON4]->() | 1]) AS season4_degree,
        SIZE([(c)-[:SEASON5]->() | 1]) AS season5_degree,
        SIZE([(c)-[:SEASON6]->() | 1]) AS season6_degree,
        SIZE([(c)-[:SEASON7]->() | 1]) AS season7_degree,
        SIZE([(c)-[:SEASON8]->() | 1]) AS season8_degree,
        (SIZE([(c)-[:SEASON1]->() | 1]) + 
        SIZE([(c)-[:SEASON2]->() | 1]) +
        SIZE([(c)-[:SEASON3]->() | 1]) +
        SIZE([(c)-[:SEASON4]->() | 1]) +
        SIZE([(c)-[:SEASON5]->() | 1]) +
        SIZE([(c)-[:SEASON6]->() | 1]) +
        SIZE([(c)-[:SEASON7]->() | 1]) +
        SIZE([(c)-[:SEASON8]->() | 1])) AS cmbdDegree 
ORDER BY season1_degree DESC 
'''
top_cat_df = pd.DataFrame([dict(_) for _ in conn.query(query_string)])
print(top_cat_df.head(10))
top_cat_10_df = top_cat_df.head(10)
# Out:
#      c.name  season1_degree  season2_degree  season3_degree  season4_degree  \
# 0   Catelyn              29              19              16              11
# 1      Arya              28              25              15              24
# 2    Cersei              23              28              18              28
# 3       Ned              23              10               7               5
# 4      Bran              18              13              17              15
# 5   Joffrey              18              23              14              26
# 6  Daenerys              17              13              10              14
# 7     Jaime              16              12              13              19
# 8     Petyr              15              13               9               8
# 9       Jon              14               6              12              20
#
#    season5_degree  season6_degree  season7_degree  season8_degree  cmbdDegree
# 0               4               5               3               0          87
# 1              11              17              18              38         176
# 2              29              24              26              16         192
# 3               4              10               4               4          67
# 4               3              14              16              29         125
# 5               7               4               8               2         102
# 6              11              16              28              32         141
# 7              11              16              12              16         115
# 8              20               7               9               1          82
# 9              18              21              24              20         135

# %%
print(top_cat_10_df)

plt.figure(figsize=(10, 6))

for i in range(len(top_cat_10_df)):
    plt.plot(top_cat_10_df.columns[1:], top_cat_10_df.iloc[i, 1:], label=top_cat_10_df.iloc[i, 0])

plt.xlabel('Seasons')
plt.ylabel('Degree')
plt.title('Degree of Characters over Seasons')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#      c.name  season1_degree  season2_degree  season3_degree  season4_degree  \
# 0   Catelyn              29              19              16              11
# 1      Arya              28              25              15              24
# 2    Cersei              23              28              18              28
# 3       Ned              23              10               7               5
# 4      Bran              18              13              17              15
# 5   Joffrey              18              23              14              26
# 6  Daenerys              17              13              10              14
# 7     Jaime              16              12              13              19
# 8     Petyr              15              13               9               8
# 9       Jon              14               6              12              20
#
#    season5_degree  season6_degree  season7_degree  season8_degree  cmbdDegree
# 0               4               5               3               0          87
# 1              11              17              18              38         176
# 2              29              24              26              16         192
# 3               4              10               4               4          67
# 4               3              14              16              29         125
# 5               7               4               8               2         102
# 6              11              16              28              32         141
# 7              11              16              12              16         115
# 8              20               7               9               1          82
# 9              18              21              24              20         135

# %%
i=1
while i<9:
    query_string = f'''
    WITH "https://raw.githubusercontent.com/mathbeveridge/gameofthrones/master/data/got-s{i}-edges.csv" AS uri
    LOAD CSV WITH HEADERS FROM uri AS row
    MERGE (source:Character {{name: row.Source}})
    MERGE (target:Character {{name: row.Target}})
    MERGE (source)-[rel:INTERACTS]->(target)
    SET rel.Weight = toInteger(row.Weight)
    RETURN source.name AS Char1, target.name AS Char2, rel.Weight AS Interactions
    ORDER BY rel.Weight DESC
    LIMIT 1
    '''
    most_interact = pd.DataFrame([dict(_) for _ in conn.query(query_string)])
    print(most_interact)
    
    i+=1
# Out:
#   Char1   Char2  Interactions
# 0   NED  ROBERT           192
#     Char1   Char2  Interactions
# 0  CERSEI  TYRION           177
#   Char1    Char2  Interactions
# 0   JON  YGRITTE           159
#   Char1  Char2  Interactions
# 0  ARYA  HOUND           162
#   Char1  Char2  Interactions
# 0  ARYA  JAQEN           148
#   Char1  Char2  Interactions
# 0   JON  SANSA           151
#       Char1   Char2  Interactions
# 0  DAENERYS  TYRION           179
#       Char1 Char2  Interactions
# 0  DAENERYS   JON           194

# %%
query_string = '''
MATCH (c:Character)-[R]-(other:Character)
WITH  toUpper(c.name) AS character_name, COUNT(DISTINCT other)/2 AS numDistInteractions
ORDER BY numDistInteractions DESC
LIMIT 10
RETURN character_name AS Character, numDistInteractions AS Distinct_Interactions
'''

distinct_interactions = pd.DataFrame([dict(_) for _ in conn.query(query_string)])
print(distinct_interactions)
# Out:
#   Character  Distinct_Interactions
# 0    TYRION                    128
# 1       JON                    105
# 2     SANSA                    101
# 3      ARYA                     97
# 4  DAENERYS                     93
# 5     JAIME                     90
# 6    CERSEI                     86
# 7       NED                     78
# 8       SAM                     78
# 9     DAVOS                     78
